# %% [markdown]
# # 課題1
#
# 与えられたリスト内重複な値を削除してください。

# %%
numbers = [1, 2, 3, 2, 4, 3, 5, 4, 6, 57, 57, 6, 18, 7, 9, 8, 10, 9, 0, 0, 10]

# %%
# 回答
numbers = [1, 2, 3, 2, 4, 3, 5, 4, 6, 57, 57, 6, 18, 7, 9, 8, 10, 9, 0, 0, 10]
unique_list = [] 
for num in numbers:
    if num not in unique_list:
        unique_list.append(num)
    else:
        continue

print(unique_list)
# Out:
# [1, 2, 3, 4, 5, 6, 57, 18, 7, 9, 8, 10, 0]

# %% [markdown]
# # 課題2
#
# 与えられたリスト内の指定した値を検索し、値の出現回数を```print```してください。見つからない場合は```Not Exists```をprintしてください。
#
# ```value_0```と```value_１```を実行した結果を確認してください。

# %%
numbers = [1, 2, 3, 2, 4, 3, 5, 4, 6, 57, 57, 6, 18, 7, 9, 8, 10, 9, 0, 0, 10]
value_0= 0
value_1= 100

# %%
# 回答
numbers = [1, 2, 3, 2, 4, 3, 5, 4, 6, 57, 57, 6, 18, 7, 9, 8, 10, 9, 0, 0, 10]
value_0= 0
value_1= 100

count_0 = 0
count_1 = 0

for num in numbers:
    if value_0 == num:
        count_0 += 1
    elif value_1 == num:
        count_1 += 1

print(count_0, count_1)
# Out:
# 2 0

# %% [markdown]
# # 課題3
#
# 与えられた辞書内の指定したに一致するキーを検索し、そのキーに対応する値を```print```してください。見つからない場合は```Not Exists```を```print```してください。
#
# ```value_0```と```value_１```を実行した結果を確認してください。

# %%
birth={'Marx': 1818,
       'Weber': 1864,
       'Durkheim': 1858,
       'Parsons': 1902,
       'Merton': 1911}

value_0= "Parsons"
value_1= "Giddens"

# %%
# 回答
birth={'Marx': 1818,
       'Weber': 1864,
       'Durkheim': 1858,
       'Parsons': 1902,
       'Merton': 1911}

value_0= "Parsons"
value_1= "Giddens"

def judge(value):
    return birth[value] if value in birth.keys() else "Not Exist"

print(judge(value_0))
print(judge(value_1))
# Out:
# 1902
# Not Exist
