# %% [markdown]
# ## 課題1
# 以下の指示に従って、```Sphere```というクラスを作成しなさい。
#
# - インスタンス化時に```radius```という値を受け取る
# - ```surface_area```というメソッドで表面積を計算する
#
# $$S = 4 \pi r^2 $$
#
# - ```volume```というメソッドで体積を計算する
#
#
# $$V = \frac{4}{3} \pi r^3 $$

# %%
class Sphere():
    pass

# %%
class sphere(): 
    def __init__(self, radius): self.radius = radius 
    def surface_area(self): return 4 * 3.14 * self.radius ** 2 
    def volume(self): return 4/ 3 *3.14 *self.radius ** 3 
print("半径3の球の表面積", sphere(3).surface_area()) 
print("半径3の球の体積", sphere(3).volume())
# Out:
# 半径3の球の表面積 113.04
# 半径3の球の体積 113.03999999999999
