# %% [markdown]
# ## 課題1
# 以下の指示に従って、```Sphere```というクラスを作成しなさい。
#
# - インスタンス化時に```radius```という値を受け取る
# - ```surface_area```というメソッドで表面積を計算する
#
# $$S = 4 \pi r^2 $$
#
# - ```volume```というメソッドで体積を計算する
#
#
# $$V = \frac{4}{3} \pi r^3 $$

# %%
import math

class Sphere():
    def __init__(self, radius):
        self.radius = radius
    
    def surface_area(self):
        S=4 * math.pi * (self.radius)**2
        print("S =", S)
    
    def volume(self):
        V=4 * math.pi * (self.radius)**3 /3
        print("V =", V)

# %%
# テスト用のコード
s = Sphere(1)
s.surface_area()
s.volume()
# Out:
# S = 12.566370614359172
# V = 4.1887902047863905
