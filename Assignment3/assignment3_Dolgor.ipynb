# %% [markdown]
#  ## 課題1
#
# 任意の二つの数の間に偶数の和を計算する関数を実装しなさい。
# 例えば、
# 入力: a = 1, b = 10 → 出力: 30（2 + 4 + 6 + 8 + 10 = 30）

# %% [markdown]
# Implement a function that calculates the sum of all even numbers between two given numbers.

# %%
#result = sum_even_numbers_between(0,10)

# %%
def sum_even_numbers_between(a, b):
    total = 0 #add up the even numbers between a and b
    for num in range(a, b + 1):
        if num % 2 == 0:
            total += num
    return total   
result = sum_even_numbers_between(0, 10)    
print(result)
# Out:
# 30

# %% [markdown]
#  ## 課題２
#
# ユークリッドの互除法の関数を作成してください。
#
# ユークリッドの互除法とは、2つの整数、aとbの最大公約数を求めるアルゴリズムです。例えば、2485と1162の最大公約数を求めたい場合
#
# $2485 \div 1162 = 2 余り 161$
#
# $1162 \div 161 = 7 余り 35$
#
# $161 \div 35 = 4 余り 21$
#
# $35 \div 21 = 1 余り 14$
#
# $21 \div 14 = 1 余り 7$
#
# $14 \div 7 = 2 余り 0$
#
# 割る数と余りを次回の割られる数と割る数にして、次々と計算し、最後に割り切れたら終わりで、最後の割る数が最大公約数です。
#
#
# - 除数が$0$によるエラーを制御してください。
# - 引数に渡す値の大小関係を考慮してください。除数が被除数より大きい場合は、自動的に値を入れ替えるように実装しなさい。

# %% [markdown]
# Create a function that implements the Euclidean Algorithm.
# The Euclidean Algorithm is a method for finding the greatest common divisor (GCD) of two integers, a and b.
# For example, suppose you want to find the GCD of 2485 and 1162.
# The omitted lines labeled 余り (remainder) are the repeated division
# 2485 ÷ 1162 = 2 remainder 161
# 1162 ÷ 161 = 7 remainder 35
# 161 ÷ 35 = 4 remainder 21
# 35 ÷ 21 = 1 remainder 14
# 21 ÷ 14 = 1 remainder 7
# 14 ÷ 7 = 2 remainder 0  steps:
# Use the divisor and the remainder as the next dividend and divisor, and continue the calculations repeatedly. When the remainder becomes zero, stop. The last divisor is the greatest common divisor.
# In the example above:
# GCD(2485, 1162) = 7
# - Handle the error that occurs when the divisor is 0
# - Take into account the relative sizes of the arguments passed to the function.
# - If the divisor is larger than the dividend, automatically swap the values before performing the calculation.

# %%
def gcd(a, b):
    if b == 0:
        return a
    if a < b: #if a < b: #If the first number/divisor is larger than the second number/dividend, swap them. 
        a, b = b, a
    while b != 0: #continue until the divisor becomes zero. 
        a, b = b, a % b
    return a
a = 2485
b = 1162
result = gcd(a, b)
print(result)
# Out:
# 7
